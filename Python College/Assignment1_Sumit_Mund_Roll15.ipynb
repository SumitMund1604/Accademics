# %% [markdown]
# # Assignment 1
#
# **Name:** Sumit Mund
# **Roll No:** 15
# **Subject:** Python Programming
#
# ---

# %% [markdown]
# ## 1. Write a Python expression to calculate the sum, difference, product and quotient of two numbers

# %%
num1 = int(input("Enter number 1: "))
num2 = int(input("Enter number 2: "))

sum_of = num1 + num2
diff = num1 - num2
product = num1 * num2
quotient = num1 / num2

print("Sum of two number is", sum_of)
print("Difference of two number is", diff)
print("Product of two number is", product)
print("Quotient of two number is", quotient)
# Out:
# Enter number 1:  12
# Enter number 2:  10
# Sum of two number is 22
# Difference of two number is 2
# Product of two number is 120
# Quotient of two number is 1.2

# %% [markdown]
# ## 2. Find remainder of a num

# %%
num1 = int(input("Enter number 1: "))
num2 = int(input("Enter number 2: "))

rim = num1 % num2
print("Riminder is", rim)
# Out:
# Enter number 1:  12
# Enter number 2:  5
# Riminder is 2

# %% [markdown]
# ## 3. Compute square and cube of a given no

# %%
num = int(input("Enter number: "))

sq = num ** 2
cube = num ** 3

print("Sqauere is:", sq)
print("cube is:", cube)
# Out:
# Enter number:  12
# Sqauere is: 144
# cube is: 1728

# %% [markdown]
# ## 4. Calculate avrage of three number

# %%
num1 = int(input("Enter number 1: "))
num2 = int(input("Enter number 2: "))
num3 = int(input("Enter number 3: "))

avg = (num1 + num2 + num3) / 3
print("Avrage of three no is", avg)
# Out:
# Enter number 1:  12
# Enter number 2:  23
# Enter number 3:  45
# Avrage of three no is 26.666666666666668

# %% [markdown]
# ## 5. Convert total second into minutes and second

# %%
sec = int(input("enter seconds"))

hour = sec // 3600
min = (sec % 3600) // 60
remaining_sec = sec % 60

print("Total hours:", hour)
print("Total Minute:", min)
print("Remaining seconds:", remaining_sec)
# Out:
# enter seconds 5996
# Total hours: 1
# Total Minute: 39
# Remaining seconds: 56

# %% [markdown]
# ## 6. Find area of a circle of a given rad

# %%
import math

r = float(input("enter radius"))
area = math.pi * r * r

print("area is", area)
# Out:
# enter radius 12
# area is 452.3893421169302

# %% [markdown]
# ## 7. Calculate simple intrest

# %%
# SI = (P × R × T) / 100
p = float(input("Enter principal amount"))
r = float(input("Enter Intrest"))
t = int(input("Enter time period"))

si = (p * r * t) / 100
print("Simple Intrest is:", si)
# Out:
# Enter principal amount 100
# Enter Intrest 2
# Enter time period 12
# Simple Intrest is: 24.0

# %% [markdown]
# ## 8. Calculate power of no using exponent operator

# %%
num = int(input("Enter a number"))

print("power of num is:", num ** 2)
# Out:
# Enter a number 12
# power of num is: 144

# %% [markdown]
# ## 9. Find Last Digit of a number

# %%
num = int(input("enter a no:"))

print("last digit is", num % 10)
# Out:
# enter a no: 123
# last digit is 3

# %% [markdown]
# ## 10. Calculate total and per of 5 subject mark

# %%
sub1 = float(input("enter marks of subject 1:"))
sub2 = float(input("enter marks of subject 2:"))
sub3 = float(input("enter marks of subject 3:"))
sub4 = float(input("enter marks of subject 4:"))
sub5 = float(input("enter marks of subject 5:"))

total_mark = sub1 + sub2 + sub3 + sub4 + sub5
print("avrage is ", total_mark / 5)
per = (total_mark / 500) * 100
print("percentage is", per)
# Out:
# enter marks of subject 1: 89
# enter marks of subject 2: 88
# enter marks of subject 3: 87
# enter marks of subject 4: 77
# enter marks of subject 5: 67
# avrage is  81.6
# percentage is 81.6

# %% [markdown]
# ## 11. Write a program to demonstarte += *=

# %%
num = int(input("enter a num"))
s = 1
s1 = 3

s += num
s1 *= num

print(s)
print(s1)
# Out:
# enter a num 12
# 13
# 36

# %% [markdown]
# ## 12. Update a variable by adding 10 and then multiply by 12

# %%
num = int(input("enter a num"))

num = (num + 10) * 12
print(num)
# Out:
# enter a num 123
# 1596

# %% [markdown]
# ## 13. Write an expresion using //= tp reduce a num

# %%
num = int(input("enter a num"))

num //= 2
print(num)
# Out:
# enter a num 123
# 61

# %% [markdown]
# ## 14. Use assignment operator to swap two no without using a third variable

# %%
num1 = int(input("enter a num1:"))
num2 = int(input("enter a num2:"))

num1 = num1 + num2
num2 = num1 - num2
num1 = num1 - num2

print("fist no is", num1)
print("Second no is", num2)
# Out:
# enter a num1: 12
# enter a num2: 20
# fist no is 20
# Second no is 12

# %% [markdown]
# ## 15. Modify a variable using %-

# %%
num = int(input("enter a num"))

num %= 5
print(num)
# Out:
# enter a num 123
# 3

# %% [markdown]
# ## 16. Find the solution of quadretic equation

# %%
# quadratic equation ax² + bx + c = 0
a = int(input("enter a coffient of x^2:"))
b = int(input("enter a coffient of x:"))
c = int(input("enter value of c :"))

root1 = (-b + ((b**2 - 4*a*c)**0.5)) / (2*a)
root2 = (-b - ((b**2 - 4*a*c)**0.5)) / (2*a)

print("Root one is", root1)
print("Root two is ", root2)
# Out:
# enter a coffient of x^2: 123
# enter a coffient of x: 12
# enter value of c : 123
# Root one is (-0.04878048780487799+0.9988095233874765j)
# Root two is  (-0.048780487804878106-0.9988095233874765j)

# %% [markdown]
# ## 17. Accept basic salary from user calculate Da(50%),hA(20%) and calculate gross salary

# %%
sal = float(input("enter your salary"))

DA = sal * 0.50
HA = sal * 0.20
Total_sal = sal + HA + DA

print("total salary is", Total_sal)
# Out:
# enter your salary 123
# total salary is 209.1

# %% [markdown]
# ## 18. Temp convert f->c and c->f

# %%
# Convert temperature between Fahrenheit and Celsius
c = float(input("Enter temp is celcius"))
f = ((9/5)*c) + 32

f1 = float(input("Enter temp is ferenhite"))
c1 = ((5/9)*f1) - 32

print("for c->f is ", f)
print("for f->c is", c1)
# Out:
# Enter temp is celcius 12
# Enter temp is ferenhite 123
# for c->f is  53.6
# for f->c is 36.33333333333334

# %% [markdown]
# ## 19. Find the sum of n natural no

# %%
# sum of n natural numbers =n(n+1)/2
n = int(input("Enter a no"))

sm = int((n*(n+1))/2)
print("Sum of n natural no is", sm)
# Out:
# Enter a no 12
# Sum of n natural no is 78

# %% [markdown]
# ## 20. Take input of two no and perform all logical and bitwise operator

# %%
# Accept two numbers and perform logical & bitwise operations
n1 = int(input("Enter a no1:"))
n2 = int(input("Enter a no2:"))

print(n1 | n2)  # or
#not
print(~ n2)
#xor
print(n1 ^ n2)
#<<left shift
print(n1 << 2)
#>> right shift
print(n1 >> 2)
# Out:
# Enter a no1: 121
# Enter a no2: 121
# 121
# -122
# 0
# 484
# 30
